# %% [markdown]
# # Create You Own built-in class method

# %% [markdown]
# Assignment 5 : OOPs
#
# Question 1
#
# Write a Python class to implement pow(x, n)
#
# Explanation:
#
# Use should be able to find the nth power of the x.(i.e x*x*x*x...n times)
#
# You must implement it using Class
#
# Sample Input:
#
# x: 10
#
# n: 2
#
# Sample Output:
#
# 100

# %%
x = int(input("Enter number :" ))
n = int(input("Enter power : "))
class power:
    def __init__ (self,x,n):
        self.x = x
        self.n = n
        self.output = 0
        self.output = pow(x,n)
        print(self.output)
print()
print('The output of above value is  : ')
find = power(x,n)
# Out:
# Enter number :10
# Enter power : 2
#
# The output of above value is  :
# 100
